# %% [markdown]
# <a href="https://colab.research.google.com/github/zebakhan694/NumPy-Assignment/blob/main/QUESTION1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr = np.identity(3, dtype=float)
arr
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
arr.dtype
# Out:
# dtype('float64')
